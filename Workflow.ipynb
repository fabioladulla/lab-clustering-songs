# %% [markdown]
# SONG RECOMMENDER - WORKFLOW

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import json
import time
import pickle
from credentialz import *
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=Client_ID,
                                                           client_secret=Client_secret))

# %%
songs = pd.read_csv('song_recommender.csv')
songs
# Out:
#                    Artist                     Title                      id  \
# 0          Olivia Rodrigo                   Vampire  4sSKTQcX6pQIncWcNJdkiD
# 1           Morgan Wallen                Last Night  59uQI0PADDKeE6UZDTJEe8
# 2              Luke Combs                  Fast Car  2M9ro2krNb7nr7HSprkEgo
# 3     Rema & Selena Gomez                 Calm Down  0WtM2NBVQNNJLh6scP13H8
# 4             Miley Cyrus                   Flowers  4DHcnVTT87F0zZhRPYmZ3B
# ...                   ...                       ...                     ...
# 2584               Wisin                Fiel  Remix  05x3RtkCoDNjvLq2bwLNwJ
# 2585             Cardi B                      Money  0PDwNx6GrHc5sRVy6Hc7GP
# 2586     Earl Sweatshirt                   The Mint  1bbASeaACA1Nx14lEHD8DX
# 2587        Thomas Rhett   What’s Your Country Song  62n7DLmd6yh8MlaxamIb2t
# 2588                  NaN                       NaN  0rOP1naZV8zL7ahMNTDXhL
#
#       energy   key  acousticness  instrumentalness  liveness    tempo  \
# 0      0.609   1.0      0.284000          0.268000    0.1120  119.973
# 1      0.675   6.0      0.459000          0.000000    0.1510  203.853
# 2      0.292   4.0      0.313000          0.000000    0.1310  103.951
# 3      0.806  11.0      0.382000          0.000669    0.1140  106.999
# 4      0.681   0.0      0.063200          0.000005    0.0322  117.999
# ...      ...   ...           ...               ...       ...      ...
# 2584   0.584  11.0      0.163000          0.000000    0.0717  116.975
# 2585   0.535   5.0      0.048300          0.000000    0.1020  117.957
# 2586   0.540  10.0      0.338000          0.000000    0.1390   78.007
# 2587   0.496   0.0      0.094500          0.000114    0.0838  140.828
# 2588   0.780   7.0      0.000135          0.301000    0.1110  120.122
#
#                 type                                   uri  \
# 0     audio_features  spotify:track:4sSKTQcX6pQIncWcNJdkiD
# 1     audio_features  spotify:track:59uQI0PADDKeE6UZDTJEe8
# 2     audio_features  spotify:track:2M9ro2krNb7nr7HSprkEgo
# 3     audio_features  spotify:track:0WtM2NBVQNNJLh6scP13H8
# 4     audio_features  spotify:track:4DHcnVTT87F0zZhRPYmZ3B
# ...              ...                                   ...
# 2584  audio_features  spotify:track:05x3RtkCoDNjvLq2bwLNwJ
# 2585  audio_features  spotify:track:0PDwNx6GrHc5sRVy6Hc7GP
# 2586  audio_features  spotify:track:1bbASeaACA1Nx14lEHD8DX
# 2587  audio_features  spotify:track:62n7DLmd6yh8MlaxamIb2t
# 2588  audio_features  spotify:track:0rOP1naZV8zL7ahMNTDXhL
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/4sSKTQcX6pQI...
# 1     https://api.spotify.com/v1/tracks/59uQI0PADDKe...
# 2     https://api.spotify.com/v1/tracks/2M9ro2krNb7n...
# 3     https://api.spotify.com/v1/tracks/0WtM2NBVQNNJ...
# 4     https://api.spotify.com/v1/tracks/4DHcnVTT87F0...
# ...                                                 ...
# 2584  https://api.spotify.com/v1/tracks/05x3RtkCoDNj...
# 2585  https://api.spotify.com/v1/tracks/0PDwNx6GrHc5...
# 2586  https://api.spotify.com/v1/tracks/1bbASeaACA1N...
# 2587  https://api.spotify.com/v1/tracks/62n7DLmd6yh8...
# 2588  https://api.spotify.com/v1/tracks/0rOP1naZV8zL...
#
#                                            analysis_url  duration_ms set  K12  \
# 0     https://api.spotify.com/v1/audio-analysis/4sSK...     300000.0   H   10
# 1     https://api.spotify.com/v1/audio-analysis/59uQ...     163855.0   H    9
# 2     https://api.spotify.com/v1/audio-analysis/2M9r...     296800.0   H   10
# 3     https://api.spotify.com/v1/audio-analysis/0WtM...     239318.0   H    4
# 4     https://api.spotify.com/v1/audio-analysis/4DHc...     200455.0   H    1
# ...                                                 ...          ...  ..  ...
# 2584  https://api.spotify.com/v1/audio-analysis/05x3...     168205.0   N    2
# 2585  https://api.spotify.com/v1/audio-analysis/0PDw...     146427.0   N    2
# 2586  https://api.spotify.com/v1/audio-analysis/1bbA...     216410.0   N    2
# 2587  https://api.spotify.com/v1/audio-analysis/62n7...     274693.0   N    7
# 2588  https://api.spotify.com/v1/audio-analysis/0rOP...     259253.0   N    4
#
#       DBSCAN2.5
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 2584          0
# 2585          0
# 2586          0
# 2587          0
# 2588          0
#
# [2589 rows x 17 columns]

# %%
songs.isnull().sum()
songs = songs.dropna()
songs
# Out:
#                    Artist                     Title                      id  \
# 0          Olivia Rodrigo                   Vampire  4sSKTQcX6pQIncWcNJdkiD
# 1           Morgan Wallen                Last Night  59uQI0PADDKeE6UZDTJEe8
# 2              Luke Combs                  Fast Car  2M9ro2krNb7nr7HSprkEgo
# 3     Rema & Selena Gomez                 Calm Down  0WtM2NBVQNNJLh6scP13H8
# 4             Miley Cyrus                   Flowers  4DHcnVTT87F0zZhRPYmZ3B
# ...                   ...                       ...                     ...
# 2583               Bazzi                   Paradise  3EdsfpdAlaQBMO0LgNOEhn
# 2584               Wisin                Fiel  Remix  05x3RtkCoDNjvLq2bwLNwJ
# 2585             Cardi B                      Money  0PDwNx6GrHc5sRVy6Hc7GP
# 2586     Earl Sweatshirt                   The Mint  1bbASeaACA1Nx14lEHD8DX
# 2587        Thomas Rhett   What’s Your Country Song  62n7DLmd6yh8MlaxamIb2t
#
#       energy   key  acousticness  instrumentalness  liveness    tempo  \
# 0      0.609   1.0        0.2840          0.268000    0.1120  119.973
# 1      0.675   6.0        0.4590          0.000000    0.1510  203.853
# 2      0.292   4.0        0.3130          0.000000    0.1310  103.951
# 3      0.806  11.0        0.3820          0.000669    0.1140  106.999
# 4      0.681   0.0        0.0632          0.000005    0.0322  117.999
# ...      ...   ...           ...               ...       ...      ...
# 2583   0.822  10.0        0.4890          0.000000    0.2840  130.825
# 2584   0.584  11.0        0.1630          0.000000    0.0717  116.975
# 2585   0.535   5.0        0.0483          0.000000    0.1020  117.957
# 2586   0.540  10.0        0.3380          0.000000    0.1390   78.007
# 2587   0.496   0.0        0.0945          0.000114    0.0838  140.828
#
#                 type                                   uri  \
# 0     audio_features  spotify:track:4sSKTQcX6pQIncWcNJdkiD
# 1     audio_features  spotify:track:59uQI0PADDKeE6UZDTJEe8
# 2     audio_features  spotify:track:2M9ro2krNb7nr7HSprkEgo
# 3     audio_features  spotify:track:0WtM2NBVQNNJLh6scP13H8
# 4     audio_features  spotify:track:4DHcnVTT87F0zZhRPYmZ3B
# ...              ...                                   ...
# 2583  audio_features  spotify:track:3EdsfpdAlaQBMO0LgNOEhn
# 2584  audio_features  spotify:track:05x3RtkCoDNjvLq2bwLNwJ
# 2585  audio_features  spotify:track:0PDwNx6GrHc5sRVy6Hc7GP
# 2586  audio_features  spotify:track:1bbASeaACA1Nx14lEHD8DX
# 2587  audio_features  spotify:track:62n7DLmd6yh8MlaxamIb2t
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/4sSKTQcX6pQI...
# 1     https://api.spotify.com/v1/tracks/59uQI0PADDKe...
# 2     https://api.spotify.com/v1/tracks/2M9ro2krNb7n...
# 3     https://api.spotify.com/v1/tracks/0WtM2NBVQNNJ...
# 4     https://api.spotify.com/v1/tracks/4DHcnVTT87F0...
# ...                                                 ...
# 2583  https://api.spotify.com/v1/tracks/3EdsfpdAlaQB...
# 2584  https://api.spotify.com/v1/tracks/05x3RtkCoDNj...
# 2585  https://api.spotify.com/v1/tracks/0PDwNx6GrHc5...
# 2586  https://api.spotify.com/v1/tracks/1bbASeaACA1N...
# 2587  https://api.spotify.com/v1/tracks/62n7DLmd6yh8...
#
#                                            analysis_url  duration_ms set  K12  \
# 0     https://api.spotify.com/v1/audio-analysis/4sSK...     300000.0   H   10
# 1     https://api.spotify.com/v1/audio-analysis/59uQ...     163855.0   H    9
# 2     https://api.spotify.com/v1/audio-analysis/2M9r...     296800.0   H   10
# 3     https://api.spotify.com/v1/audio-analysis/0WtM...     239318.0   H    4
# 4     https://api.spotify.com/v1/audio-analysis/4DHc...     200455.0   H    1
# ...                                                 ...          ...  ..  ...
# 2583  https://api.spotify.com/v1/audio-analysis/3Eds...     211400.0   N    4
# 2584  https://api.spotify.com/v1/audio-analysis/05x3...     168205.0   N    2
# 2585  https://api.spotify.com/v1/audio-analysis/0PDw...     146427.0   N    2
# 2586  https://api.spotify.com/v1/audio-analysis/1bbA...     216410.0   N    2
# 2587  https://api.spotify.com/v1/audio-analysis/62n7...     274693.0   N    7
#
#       DBSCAN2.5
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 2583          0
# 2584          0
# 2585          0
# 2586          0
# 2587          0
#
# [2588 rows x 17 columns]

# %%
# Change all string values in the dataframe to lowercase
songs[['Artist', 'Title']] = songs[['Artist', 'Title']].applymap(lambda s: s.lower() if type(s) == str else s)
songs
# Out:
#                    Artist                     Title                      id  \
# 0          olivia rodrigo                   vampire  4sSKTQcX6pQIncWcNJdkiD
# 1           morgan wallen                last night  59uQI0PADDKeE6UZDTJEe8
# 2              luke combs                  fast car  2M9ro2krNb7nr7HSprkEgo
# 3     rema & selena gomez                 calm down  0WtM2NBVQNNJLh6scP13H8
# 4             miley cyrus                   flowers  4DHcnVTT87F0zZhRPYmZ3B
# ...                   ...                       ...                     ...
# 2583               bazzi                   paradise  3EdsfpdAlaQBMO0LgNOEhn
# 2584               wisin                fiel  remix  05x3RtkCoDNjvLq2bwLNwJ
# 2585             cardi b                      money  0PDwNx6GrHc5sRVy6Hc7GP
# 2586     earl sweatshirt                   the mint  1bbASeaACA1Nx14lEHD8DX
# 2587        thomas rhett   what’s your country song  62n7DLmd6yh8MlaxamIb2t
#
#       energy   key  acousticness  instrumentalness  liveness    tempo  \
# 0      0.609   1.0        0.2840          0.268000    0.1120  119.973
# 1      0.675   6.0        0.4590          0.000000    0.1510  203.853
# 2      0.292   4.0        0.3130          0.000000    0.1310  103.951
# 3      0.806  11.0        0.3820          0.000669    0.1140  106.999
# 4      0.681   0.0        0.0632          0.000005    0.0322  117.999
# ...      ...   ...           ...               ...       ...      ...
# 2583   0.822  10.0        0.4890          0.000000    0.2840  130.825
# 2584   0.584  11.0        0.1630          0.000000    0.0717  116.975
# 2585   0.535   5.0        0.0483          0.000000    0.1020  117.957
# 2586   0.540  10.0        0.3380          0.000000    0.1390   78.007
# 2587   0.496   0.0        0.0945          0.000114    0.0838  140.828
#
#                 type                                   uri  \
# 0     audio_features  spotify:track:4sSKTQcX6pQIncWcNJdkiD
# 1     audio_features  spotify:track:59uQI0PADDKeE6UZDTJEe8
# 2     audio_features  spotify:track:2M9ro2krNb7nr7HSprkEgo
# 3     audio_features  spotify:track:0WtM2NBVQNNJLh6scP13H8
# 4     audio_features  spotify:track:4DHcnVTT87F0zZhRPYmZ3B
# ...              ...                                   ...
# 2583  audio_features  spotify:track:3EdsfpdAlaQBMO0LgNOEhn
# 2584  audio_features  spotify:track:05x3RtkCoDNjvLq2bwLNwJ
# 2585  audio_features  spotify:track:0PDwNx6GrHc5sRVy6Hc7GP
# 2586  audio_features  spotify:track:1bbASeaACA1Nx14lEHD8DX
# 2587  audio_features  spotify:track:62n7DLmd6yh8MlaxamIb2t
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/4sSKTQcX6pQI...
# 1     https://api.spotify.com/v1/tracks/59uQI0PADDKe...
# 2     https://api.spotify.com/v1/tracks/2M9ro2krNb7n...
# 3     https://api.spotify.com/v1/tracks/0WtM2NBVQNNJ...
# 4     https://api.spotify.com/v1/tracks/4DHcnVTT87F0...
# ...                                                 ...
# 2583  https://api.spotify.com/v1/tracks/3EdsfpdAlaQB...
# 2584  https://api.spotify.com/v1/tracks/05x3RtkCoDNj...
# 2585  https://api.spotify.com/v1/tracks/0PDwNx6GrHc5...
# 2586  https://api.spotify.com/v1/tracks/1bbASeaACA1N...
# 2587  https://api.spotify.com/v1/tracks/62n7DLmd6yh8...
#
#                                            analysis_url  duration_ms set  K12  \
# 0     https://api.spotify.com/v1/audio-analysis/4sSK...     300000.0   H   10
# 1     https://api.spotify.com/v1/audio-analysis/59uQ...     163855.0   H    9
# 2     https://api.spotify.com/v1/audio-analysis/2M9r...     296800.0   H   10
# 3     https://api.spotify.com/v1/audio-analysis/0WtM...     239318.0   H    4
# 4     https://api.spotify.com/v1/audio-analysis/4DHc...     200455.0   H    1
# ...                                                 ...          ...  ..  ...
# 2583  https://api.spotify.com/v1/audio-analysis/3Eds...     211400.0   N    4
# 2584  https://api.spotify.com/v1/audio-analysis/05x3...     168205.0   N    2
# 2585  https://api.spotify.com/v1/audio-analysis/0PDw...     146427.0   N    2
# 2586  https://api.spotify.com/v1/audio-analysis/1bbA...     216410.0   N    2
# 2587  https://api.spotify.com/v1/audio-analysis/62n7...     274693.0   N    7
#
#       DBSCAN2.5
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 2583          0
# 2584          0
# 2585          0
# 2586          0
# 2587          0
#
# [2588 rows x 17 columns]

# %%
import pandas as pd

# assume df is your DataFrame
def search_song(title, artist):
    
    query = "tracks: "+title+" artist: "+artist

    try:
        result = sp.search(query, limit=1)
        song_id = result['tracks']['items'][0]['id']
    except:
        song_id = "not_found"

    return song_id 

def song_is_hot(df: pd.DataFrame, song_id:str):
    if (song_id in df['id'].values):
        return "Yes"
    else:
        return "No"

def get_audio_features(song_id):
    
    # Retrieve the audio features for each chunk
    audio_features = sp.audio_features(song_id)[0]
    
    audio_features_dict = { key: [audio_features[key]] for key in list(audio_features.keys())}
    
    df = pd.DataFrame(audio_features_dict)

    return df

def scale_audio_features(df: pd.DataFrame, filename="scaler.pickle"):
    
    try:
        with open(filename, "rb") as file:
            scaler = pickle.load(file)
    except:
        print("Scaler not found!!!")
    
    scaled_audio_features_np = scaler.transform(df[['energy','key','acousticness','instrumentalness','liveness','tempo','duration_ms']])

    scaled_audio_features_df = pd.DataFrame(scaled_audio_features_np, columns=['energy','key','acousticness','instrumentalness','liveness','tempo','duration_ms'])

    return scaled_audio_features_df


def get_user_song_cluster(scaled_audio_features_df: pd.DataFrame, filename="kmeans_12.pickle"):
    
    try:
        with open(filename, "rb") as file:
            model = pickle.load(file)
    except FileNotFound:
        print("Model not found!!!")
              
    user_song_cluster = model.predict(scaled_audio_features_df)[0]
              
    return user_song_cluster
    
def recommend_song(df):
    
    song_title = input("Enter the song title: ")
    artist_name = input("Enter the artist name: ")
        
    # Get user's song id
    song_id = search_song(song_title, artist_name)
        
    # Determine if the user's song is hot
    is_hot = song_is_hot(df, song_id)
        
    # Get the audio_features of user's song
    user_song_audio_features_df = get_audio_features([song_id])
    
    # Scale the user's song audio features
    user_song_scaled_audio_features_df = scale_audio_features(user_song_audio_features_df)
        
    # Determine the user's song cluster
    user_song_cluster = get_user_song_cluster(user_song_scaled_audio_features_df)

    if ( is_hot == "Yes" ): # Recommend another hot song from the the same cluster:
        subset = df[(df['set'] == "H") & (df['K12'] == user_song_cluster)]
        if len(subset) < 5:
            rec_song = df[(df['set'] == "H") & (df['K12'] == user_song_cluster) ].sample(len(subset))
        else:
            rec_song = df[(df['set'] == "H") & (df['K12'] == user_song_cluster) ].sample(5)
    else: # Recommend another not hot song from the same cluster
        subset = df[(df['set'] == "H") & (df['K12'] == user_song_cluster)]
        if len(subset) < 5:
            rec_song = df[(df['set'] == "N") &(df['K12'] == user_song_cluster)].sample(len(subset))
        else:
            rec_song = df[(df['set'] == "N") &(df['K12'] == user_song_cluster)].sample(5)
        
    rec_song['Listen to Your Songs Now'] = 'https://open.spotify.com/track/' + rec_song['id']
    
    print("We recommend you the following songs")
              
    with pd.option_context('display.max_colwidth', None):
        display(rec_song[['Title','Artist','Listen to Your Songs Now']])
              

def ask_user_for_another_song():

    answer = input("Do you want another recommendation? (yes/no): ")
    answer = answer.lower()
              
    while answer not in ["yes","no"]:
        print("Invalid input. Please enter 'yes' or 'no'.")
        print()
        answer = input("Do you want another recommendation? (yes/no): ")
        answer = answer.lower()
    
    return answer

            
def song_recommender(df):
              
    answer = "yes"
    while answer == "yes":
        recommend_song(df)
        answer = ask_user_for_another_song()

# %%
song_recommender(songs)
# Out:
# Enter the song title:  dance the night
# Enter the artist name:  dua lipa
# We recommend you the following songs
#                      Title                               Artist  \
# 49     party in the u.s.a.                          miley cyrus
# 30                     aye  lil uzi vert featuring travis scott
# 36  dancin' in the country                        tyler hubbard
# 82       everything i love                        morgan wallen
# 59           pluto to mars                         lil uzi vert
#
#                                  Listen to Your Songs Now
# 49  https://open.spotify.com/track/5Q0Nhxo0l2bP3pNjpGJwV1
# 30  https://open.spotify.com/track/2Hc1LaV6bzFil3dE71eORA
# 36  https://open.spotify.com/track/2KtGiBi5CrX2ERPD2PAS34
# 82  https://open.spotify.com/track/03fs6oV5JAlbytRYf3371S
# 59  https://open.spotify.com/track/0WCJSIy75ZVxqY51ce0enc
# Do you want another recommendation? (yes/no):  yes
# Enter the song title:  money
# Enter the artist name:  cardi b
# We recommend you the following songs
#               Title          Artist  \
# 2          fast car      luke combs
# 37  search & rescue           drake
# 0           vampire  olivia rodrigo
#
#                                  Listen to Your Songs Now
# 2   https://open.spotify.com/track/2M9ro2krNb7nr7HSprkEgo
# 37  https://open.spotify.com/track/7aRCf5cLOFN1U7kvtChY1G
# 0   https://open.spotify.com/track/4sSKTQcX6pQIncWcNJdkiD
# Do you want another recommendation? (yes/no):  sultans of swing
# Invalid input. Please enter 'yes' or 'no'.
# Do you want another recommendation? (yes/no):  yes
# Enter the song title:  sultans of swing
# Enter the artist name:  dire strait
# We recommend you the following songs
#          Title          Artist  \
# 2430     34+35  ariana grande
# 2157  low life        soleima
# 179     static     steve lacy
#
#                                    Listen to Your Songs Now
# 2430  https://open.spotify.com/track/1m2xMsxbtxv21Brome189p
# 2157  https://open.spotify.com/track/1wlKw9NAWVWpx7OIAyg9EA
# 179   https://open.spotify.com/track/40riOy7x9W7GXjyGp4pjAv
# Do you want another recommendation? (yes/no):  no
